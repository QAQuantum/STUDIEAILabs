# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Winfredy/SadTalker/blob/main/quick_demo.ipynb)

# %% [markdown]
# Installation (around 5 mins)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pwd
# Out:
# '/content'

# %%
# %cd /content/drive/MyDrive/VoiceClone/Experiment_Audio
# Out:
# /content/drive/MyDrive/VoiceClone/Experiment_Audio

# %%
pwd
# Out:
# '/content/drive/MyDrive/VoiceClone/Experiment_Audio'

# %%
# !pip install pydub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import glob
import sys
import os
from pydub import AudioSegment

# %%
##https://www.youtube.com/watch?v=zpOK4wjC4h4


yt = YouTube(str("https://www.youtube.com/watch?v=rkZzg7Vowao"))

video = yt.streams.filter(only_audio = True).first()
destination = '.'
out_file = video.download(output_path = destination)
base, ext = os.path.splitext(out_file)
new_file = base + '.mp3'
os.rename(out_file, new_file)

# %%
# !youtube-dl https://www.youtube.com/watch?v=rkZzg7Vowao
# Out:
# [youtube] rkZzg7Vowao: Downloading webpage
# ERROR: Unable to extract uploader id; please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; see  https://yt-dl.org/update  on how to update. Be sure to call youtube-dl with the --verbose flag and include its complete output.
