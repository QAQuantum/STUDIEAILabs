# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Winfredy/SadTalker/blob/main/quick_demo.ipynb)

# %% [markdown]
# Installation (around 5 mins)

# %%
#REF - https://www.youtube.com/watch?v=rkZzg7Vowao

# DOWNLOAD VIDEO - https://www.javatpoint.com/how-to-download-youtube-videos-using-python-scripts

#https://stackoverflow.com/questions/72965406/no-sound-in-video-downloaded-from-youtube-using-pytube


# Step 1 : Download  YOutube VIDEO 
# Step 2 : Map  converted audio  to the video

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pwd
# Out:
# '/content'

# %%
# %cd /content/drive/MyDrive/VoiceClone/Experiment_Audio
# Out:
# /content/drive/MyDrive/VoiceClone/Experiment_Audio

# %%
pwd
# Out:
# '/content/drive/MyDrive/VoiceClone/Experiment_Audio'

# %%
# !pip install pytube
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from pytube import YouTube 
import os
import os
import pytube
import moviepy.editor as mpe
from moviepy.editor import VideoFileClip, AudioFileClip, concatenate_videoclips

# %%
includeDir = "/content/drive/MyDrive/VoiceClone/Experiment_Audio/"

# %%
# link of the video to be downloaded
link="https://www.youtube.com/watch?v=rkZzg7Vowao"


# Download video and rename
video = pytube.YouTube(link).streams.filter(subtype='mp4', res="720p", only_video=True).first().download()
os.rename(video, "Scientist_NO_VOICE")

# %%
#####################################  SAVE VIDEO TO A LOCATION 
#####################################  SAVE VIDEO TO A LOCATION 
#####################################  SAVE VIDEO TO A LOCATION 
#####################################  SAVE VIDEO TO A LOCATION 
#####################################   GIVE IT TO VIDEO MAKER SOFTWARE TO PATCH NO VOICE VIDEO AND LANGUAGE GENERATED AUDIO 
#################################### THEN AGAIN SAVE IT AFTER PATCHING AS A COURSE
# Out:
# '/content/drive/MyDrive/VoiceClone/Experiment_Audio/The Man Who Revolutionized Computer Science With Math.mp4'

# %%
# # Open the video and audio
# video_clip = VideoFileClip(includeDir+"Scientist_NO_VOICE")
# audio_clip = AudioFileClip(includeDir + "SciAudio/"+"AUDIO_Scientist_Dutch_AUDIO_MAIN.mp3")

# %%
# # Concatenate the video clip with the audio clip
# final_clip = video_clip.set_audio(audio_clip)

# %%
# # Export the final video with audio
# final_clip.write_videofile("VIDEO_DUTCH_Scientist" + ".mp4")
# Out:
# Moviepy - Building video VIDEO_DUTCH_Scientist.mp4.
# MoviePy - Writing audio in VIDEO_DUTCH_ScientistTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video VIDEO_DUTCH_Scientist.mp4
# Moviepy - Done !
# Moviepy - video ready VIDEO_DUTCH_Scientist.mp4
