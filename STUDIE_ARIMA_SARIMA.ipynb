# %%
#FILE PATH
#/content/drive/MyDrive/Colab Notebooks/USECASE_1.xlsx

# %%
import pandas as pd
import datetime

# %%
df = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/USECASE_1.xlsx')

# %%
df
# Out:
#    AssessmentDate                                   AssessmentTopics  Count  \
# 0      2024-05-28  Benefits of Dermatology, Benefits of Vermosics...     43
# 1      2024-05-29  Benefits of Dermatology, Benefits of Vermosics...     35
# 2      2024-05-30  Benefits of Dermatology, Benefits of Vermosics...     22
# 3      2024-05-31  Benefits of Dermatology, Benefits of Vermosics...     31
# 4      2024-06-01  Benefits of Dermatology, Benefits of Vermosics...     19
# 5      2024-06-02  Benefits of Dermatology, Benefits of Vermosics...     16
# 6      2024-06-03  Benefits of Dermatology, Benefits of Vermosics...     53
# 7      2024-06-04  Benefits of Dermatology, Benefits of Vermosics...     20
# 8      2024-06-05  Benefits of Dermatology, Benefits of Vermosics...     64
# 9      2024-06-06  Benefits of Dermatology, Benefits of Vermosics...    144
# 10     2024-06-07  Benefits of Dermatology, Benefits of Vermosics...     19
# ...

# %%
df = df[["AssessmentDate","Count"]]

# %%
df.index = pd.to_datetime(df['AssessmentDate'], format='%Y-%m-%d')

# %%
df
# Out:
#                AssessmentDate  Count
# AssessmentDate
# 2024-05-28         2024-05-28     43
# 2024-05-29         2024-05-29     35
# 2024-05-30         2024-05-30     22
# 2024-05-31         2024-05-31     31
# 2024-06-01         2024-06-01     19
# 2024-06-02         2024-06-02     16
# 2024-06-03         2024-06-03     53
# 2024-06-04         2024-06-04     20
# 2024-06-05         2024-06-05     64
# 2024-06-06         2024-06-06    144
# 2024-06-07         2024-06-07     19
# 2024-06-08         2024-06-08     43
# 2024-06-09         2024-06-09     15
# 2024-06-10         2024-06-10     24
# 2024-06-11         2024-06-11     11
# 2024-06-12         2024-06-12     43
# 2024-06-13         2024-06-13     34
# 2024-06-14         2024-06-14     15
# 2024-06-15         2024-06-15     13
# 2024-06-16         2024-06-16     24

# %%
del df['AssessmentDate']

# %%
df
# Out:
#                 Count
# AssessmentDate
# 2024-05-28         43
# 2024-05-29         35
# 2024-05-30         22
# 2024-05-31         31
# 2024-06-01         19
# 2024-06-02         16
# 2024-06-03         53
# 2024-06-04         20
# 2024-06-05         64
# 2024-06-06        144
# 2024-06-07         19
# 2024-06-08         43
# 2024-06-09         15
# 2024-06-10         24
# 2024-06-11         11
# 2024-06-12         43
# 2024-06-13         34
# 2024-06-14         15
# 2024-06-15         13
# 2024-06-16         24

# %%
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.model_selection import train_test_split

# %%
plt.ylabel('Count')
plt.xlabel('AssessmentDate')
plt.xticks(rotation=45)
plt.plot(df.index,df['Count'],)

# %%
df.shape[0]
# Out:
# 20

# %%
# SPLIT DATA FOR TRAINING AND TESTING
train = df[df.index < pd.to_datetime("2024-06-09", format='%Y-%m-%d')]
test = df[df.index >= pd.to_datetime("2024-06-09", format='%Y-%m-%d')]
# size =  0.75
# totalrows =  df.shape[0]

# size = int(totalrows * size)

# train =  df[0:size]
# test =  df[size:]

# %%
train
# Out:
#                 Count
# AssessmentDate
# 2024-05-28         43
# 2024-05-29         35
# 2024-05-30         22
# 2024-05-31         31
# 2024-06-01         19
# 2024-06-02         16
# 2024-06-03         53
# 2024-06-04         20
# 2024-06-05         64
# 2024-06-06        144
# 2024-06-07         19
# 2024-06-08         43

# %%
test
# Out:
#                 Count
# AssessmentDate
# 2024-06-09         15
# 2024-06-10         24
# 2024-06-11         11
# 2024-06-12         43
# 2024-06-13         34
# 2024-06-14         15
# 2024-06-15         13
# 2024-06-16         24

# %%
plt.plot(train, color = "black")
plt.plot(test, color = "red")
plt.ylabel('Assessment Count')
plt.xlabel('Assessment Date')
plt.xticks(rotation=45)
plt.title("Train/Test split for STUDIE Assessments")
plt.show()

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
y =  train['Count']

# %%
y
# Out:
# AssessmentDate
# 2024-05-28     43
# 2024-05-29     35
# 2024-05-30     22
# 2024-05-31     31
# 2024-06-01     19
# 2024-06-02     16
# 2024-06-03     53
# 2024-06-04     20
# 2024-06-05     64
# 2024-06-06    144
# 2024-06-07     19
# 2024-06-08     43
# Name: Count, dtype: int64

# %%
def dataARMA(orders):
  ARMAmodel = SARIMAX(y, order = orders)#(1, 2, 1)
  ARMAmodel = ARMAmodel.fit()
  y_pred = ARMAmodel.get_forecast(len(test.index))
  y_pred_df = y_pred.conf_int(alpha = 0.05)
  y_pred_df["Predictions"] = ARMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
  y_pred_df.index = test.index
  y_pred_out = y_pred_df["Predictions"]
  # plt.plot(y_pred_out, color='green', label = 'Predictions')
  # plt.legend()
  arma_rmse = np.sqrt(mean_squared_error(test["Count"].values, y_pred_df["Predictions"]))
  print("RMSE : ",arma_rmse)
  print("ORDER : ",orders)
  print("-----------------------------------------")

# %%
p_values = [0, 1, 2, 4, 6, 8, 10]
d_values = [0,1,2,3]
q_values = [0,1,2,3]

for p in p_values:
  for d in d_values:
    for q in q_values:
      order = (p,d,q)
      dataARMA(order)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ...

# %%
# (1, 2, 1)  is the best hyper parameter
ARMAmodel = SARIMAX(y, order = (1,2,1))#(1, 2, 1)
ARMAmodel = ARMAmodel.fit()
y_pred = ARMAmodel.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha = 0.05)
y_pred_df["Predictions"] = ARMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]
plt.plot(y_pred_out, color='green', label = 'Predictions')
plt.legend()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'

# %%
# y_pred_out

# %%
# 2024-06-09	15
# 2024-06-10	24
# 2024-06-11	11
# 2024-06-12	43
# 2024-06-13	34
# 2024-06-14	15
# 2024-06-15	13
# 2024-06-16	24

# %%
import numpy as np
from sklearn.metrics import mean_squared_error

arma_rmse = np.sqrt(mean_squared_error(test["Count"].values, y_pred_df["Predictions"]))
print("RMSE: ",arma_rmse)
# Out:
# RMSE:  15.798893412938293

# %%
# ARMA MODEL FALLS FOR STATIONARITY AND SEASONALITY as it does not consider them
# RMSE is HIGH - it couldn't predict the data well because of above factors

# %%
# ARIMA MODEl

from statsmodels.tsa.arima.model import ARIMA

# %%
ARIMAmodel = ARIMA(y, order = (5,2,2))
ARIMAmodel = ARIMAmodel.fit()

y_pred = ARIMAmodel.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha = 0.05)
y_pred_df["Predictions"] = ARIMAmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]
plt.plot(y_pred_out, color='Yellow', label = 'ARIMA Predictions')
plt.legend()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'

# %%
import numpy as np
from sklearn.metrics import mean_squared_error

arma_rmse = np.sqrt(mean_squared_error(test["Count"].values, y_pred_df["Predictions"]))
print("RMSE: ",arma_rmse)

#= (1, 3, 3)) - 45
# Out:
# RMSE:  140.1651047084565

# %%
test['Count']
# Out:
# AssessmentDate
# 2024-06-09    15
# 2024-06-10    24
# 2024-06-11    11
# 2024-06-12    43
# 2024-06-13    34
# 2024-06-14    15
# 2024-06-15    13
# 2024-06-16    24
# Name: Count, dtype: int64

# %%
#SARIMAX WITH SEASONALITY FACTOR
SARIMAXmodel = SARIMAX(y, order = (5, 4, 2), seasonal_order=(2,2,2,12))
SARIMAXmodel = SARIMAXmodel.fit()

y_pred = SARIMAXmodel.get_forecast(len(test.index))
y_pred_df = y_pred.conf_int(alpha = 0.05)
y_pred_df["Predictions"] = SARIMAXmodel.predict(start = y_pred_df.index[0], end = y_pred_df.index[-1])
y_pred_df.index = test.index
y_pred_out = y_pred_df["Predictions"]
plt.plot(y_pred_out, color='Blue', label = 'SARIMA Predictions')
plt.legend()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for ARMA and trend. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'

# %%
import numpy as np
from sklearn.metrics import mean_squared_error

arma_rmse = np.sqrt(mean_squared_error(test["Count"].values, y_pred_df["Predictions"]))
print("RMSE: ",arma_rmse)

#= (1, 3, 3)) - 45
# Out:
# RMSE:  23302.65237706011
